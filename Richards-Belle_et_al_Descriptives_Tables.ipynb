# %% [markdown]
# # Longitudinal associations between stroke and psychosis: a population-based study of older adults

# %% [markdown]
# ## Calculate descriptive statistics

# %% [markdown]
# Load necessary packages

# %%
library(dplyr)
library(gtsummary)
library(gt)
library(IRdisplay)
library(webshot2)

# %%
# Exporting tables to images from gtsummary requires PhantomJS to be installed
# It can be installed via the webshot2 package from the R prompt using the following commands
# library(webshot2)
# install_phantomjs()

# %% [markdown]
# Load pre-processed dataframes created by Stroke_Psychosis_ELSA_Pre-processing.R

# %%
# Location of pre-processed dataframe files
transformed_data_dir = "/home/main/data/StrokePsychosisELSATransformedData/"

# Directory to store the generated tables as html files. Must be writeable.
output_dir <- "/tmp/"

transformed_data_filename = paste(transformed_data_dir, "waves12345.rda", sep="")
load(file = transformed_data_filename)

strokeinpsychosis_surv_filename = paste(transformed_data_dir, "strokeinpsychosis_surv.rda", sep="")
load(file = strokeinpsychosis_surv_filename)

# %%
# Create variable defining stroke/psychosis categories for tables
strokeinpsychosis_surv <- strokeinpsychosis_surv %>%
  mutate(categories = case_when(strokeever_10 == 1 & psychosisever_10 == 0 ~ "Stroke only", # had stroke within 10 years, but no psychosis
                                strokeever_10 == 0 & psychosisever_10 == 1 ~ "Psychosis only", # had psychosis within 10 years, but no stroke
                                strokeever_10 == 1 & psychosisever_10 == 1 ~ "Stroke and Psychosis", # had stroke and psychosis within 10 years
                                strokeever_10 == 0 & psychosisever_10 == 0 ~ "No Stroke or Psychosis", # had no stroke or psychosis within 10 years (but may have had them after 10 years)
                                TRUE ~ "Error"))

# Merge with waves12345 which has the other required variables
strokeinpsychosis_surv <- merge(strokeinpsychosis_surv, waves12345, by="idauniq", all = TRUE)

# %% [markdown]
# ### Table 1. Demographics and descriptive statistics for sample

# %%
table_1 <- strokeinpsychosis_surv %>%
  select(categories, w1age.y, age_cat.y, Sex = sex.y, Ethnicity = ethnicgroup.y,
         netwealth_q5.y, smokingbaseline.y, vigorousactbaseline.y, alcoholbaseline.y) %>%
  tbl_summary(
    by = categories,
    sort = everything() ~ "alphanumeric",
    label = list(w1age.y = "Age at Wave 1, median (IQR)",
                 age_cat.y = "Age categories, n (%)",
                 netwealth_q5.y = "Net financial wealth (quintile), n (%)",
                 smokingbaseline.y = "Smoked cigarettes at baseline, n (%)",
                 vigorousactbaseline.y = "Level of vigorous activity at baseline, n (%)",
                 alcoholbaseline.y = "Level of alcohol consumption at baseline, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Table 1. Demographics and descriptive statistics for sample**")

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
table_1_filename = paste(output_dir, "RB_et_al_table_1.html", sep="")
gt::gtsave(as_gt(table_1), file = table_1_filename)
display_html(file = table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="qgjcejrynq" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #qgjcejrynq .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #qgjcejrynq .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #qgjcejrynq .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #qgjcejrynq .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #qgjcejrynq .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #qgjcejrynq .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #qgjcejrynq .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #qgjcejrynq .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #qgjcejrynq .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #qgjcejrynq .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #qgjcejrynq .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #qgjcejrynq .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #qgjcejrynq .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qgjcejrynq .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #qgjcejrynq .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #qgjcejrynq .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qgjcejrynq .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #qgjcejrynq .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qgjcejrynq .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #qgjcejrynq .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qgjcejrynq .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #qgjcejrynq .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qgjcejrynq .gt_left {
#   text-align: left;
# }
#
# #qgjcejrynq .gt_center {
#   text-align: center;
# }
#
# #qgjcejrynq .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #qgjcejrynq .gt_font_normal {
#   font-weight: normal;
# }
#
# #qgjcejrynq .gt_font_bold {
#   font-weight: bold;
# }
#
# #qgjcejrynq .gt_font_italic {
#   font-

# %% [markdown]
# ### Supplementary Table 1. Stroke status and every-reported psychiatric diagnoses for sample

# %%
suppl_table_1 <- strokeinpsychosis_surv %>%
  select(categories, minstrokeage, ntotalstrokes, ntotalstrokesnozero, depressionever, anxietyever) %>%
  tbl_summary(
    by = categories,
    type = list(depressionever ~ "dichotomous",
                anxietyever ~ "dichotomous",
                ntotalstrokesnozero ~ "continuous"),
    statistic = list(ntotalstrokes ~ "{mean} ({sd})",
                     ntotalstrokesnozero ~ "{mean} ({sd})"),
    digits = list(ntotalstrokes ~ 1,
                  ntotalstrokesnozero ~ 1),
    sort = everything() ~ "alphanumeric",
    label = list(
                 minstrokeage = "Age at first stroke, median (IQR)",
                 ntotalstrokes = "Number of stroke recurrences, mean (SD)",
                 ntotalstrokesnozero = "Number of stroke recurrences (if >0), mean (SD)",
                 depressionever = "Ever-reported Depression, n (%)",
                 anxietyever = "Ever-reported Anxiety, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Supplementary Table 1. Stroke characteristics and psychiatric comorbidities across Stroke and Psychosis groups**") #%>%

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
suppl_table_1_filename = paste(output_dir, "RB_et_al_suppl_table_1.html", sep="")
gt::gtsave(as_gt(suppl_table_1), file = suppl_table_1_filename)
display_html(file = suppl_table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="qawdvambwb" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #qawdvambwb .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #qawdvambwb .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #qawdvambwb .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #qawdvambwb .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #qawdvambwb .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #qawdvambwb .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #qawdvambwb .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #qawdvambwb .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #qawdvambwb .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #qawdvambwb .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #qawdvambwb .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #qawdvambwb .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #qawdvambwb .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qawdvambwb .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #qawdvambwb .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #qawdvambwb .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qawdvambwb .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #qawdvambwb .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qawdvambwb .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #qawdvambwb .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qawdvambwb .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #qawdvambwb .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #qawdvambwb .gt_left {
#   text-align: left;
# }
#
# #qawdvambwb .gt_center {
#   text-align: center;
# }
#
# #qawdvambwb .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #qawdvambwb .gt_font_normal {
#   font-weight: normal;
# }
#
# #qawdvambwb .gt_font_bold {
#   font-weight: bold;
# }
#
# #qawdvambwb .gt_font_italic {
#   font-

# %% [markdown]
# NB: Number of stroke reoccurences are reported for the No Stroke or Psychosis group in this table but are not included in the manuscript table. Some of the No Stroke and Psychosis group had strokes and recurrent strokes after the 10 year period that this study covers, and so although they are calculated by the code, they are not reported in this table in the manuscript.

# %% [markdown]
# ### Supplementary Table 2. Study participation across stroke and psychosis groups.

# %%
suppl_table_2 <- strokeinpsychosis_surv %>%
  select(categories, totalwaves, allwavesparticipated, diedbeforeendfup) %>%
  tbl_summary(
    by = categories,
    type = totalwaves ~ "continuous",
    digits = totalwaves ~ 1,
    sort = everything() ~ "alphanumeric",
    label = list(
                 totalwaves = "Number of waves participated, median (IQR)",
                 allwavesparticipated = "Participated in all waves, n (%)",
                 diedbeforeendfup = "Died before Wave 6, n (%)")
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Supplementary Table 2. Study participation across Stroke and Psychosis groups**") # %>%

suppl_table_2_filename = paste(output_dir, "RB_et_al_suppl_table_2.html", sep="")
gt::gtsave(as_gt(suppl_table_2), file = suppl_table_2_filename)
display_html(file = suppl_table_2_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="kdcdvopqgp" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #kdcdvopqgp .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #kdcdvopqgp .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #kdcdvopqgp .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #kdcdvopqgp .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #kdcdvopqgp .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #kdcdvopqgp .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #kdcdvopqgp .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #kdcdvopqgp .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #kdcdvopqgp .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #kdcdvopqgp .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #kdcdvopqgp .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #kdcdvopqgp .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #kdcdvopqgp .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #kdcdvopqgp .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #kdcdvopqgp .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #kdcdvopqgp .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #kdcdvopqgp .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #kdcdvopqgp .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #kdcdvopqgp .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #kdcdvopqgp .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #kdcdvopqgp .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #kdcdvopqgp .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #kdcdvopqgp .gt_left {
#   text-align: left;
# }
#
# #kdcdvopqgp .gt_center {
#   text-align: center;
# }
#
# #kdcdvopqgp .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #kdcdvopqgp .gt_font_normal {
#   font-weight: normal;
# }
#
# #kdcdvopqgp .gt_font_bold {
#   font-weight: bold;
# }
#
# #kdcdvopqgp .gt_font_italic {
#   font-

# %% [markdown]
# ## Analysis platform details and software versions

# %%
version
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          2.0
# year           2022
# month          04
# day            22
# svn rev        82229
# language       R
# version.string R version 4.2.0 (2022-04-22)
# nickname       Vigorous Calisthenics

# %%
packageVersion("dplyr")
# Out:
# [1] ‘1.0.9’

# %%
packageVersion("gtsummary")
# Out:
# [1] ‘1.6.2’

# %%
packageVersion("gt")
# Out:
# [1] ‘0.7.0’

# %%
packageVersion("IRdisplay")
# Out:
# [1] ‘1.1’

# %%
packageVersion("webshot2")
# Out:
# [1] ‘0.1.0’
