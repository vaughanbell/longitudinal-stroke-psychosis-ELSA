# %% [markdown]
# # Longitudinal associations between stroke and psychosis: a population-based study of older adults

# %% [markdown]
# ## Calculate descriptive statistics

# %% [markdown]
# Load necessary packages

# %%
library(dplyr)
library(gtsummary)
library(gt)
library(IRdisplay)
library(webshot2)

# %%
# Exporting tables to images from gtsummary requires PhantomJS to be installed
# It can be installed via the webshot2 package from the R prompt using the following commands
# library(webshot2)
# install_phantomjs()

# %% [markdown]
# Load pre-processed dataframes created by Stroke_Psychosis_ELSA_Pre-processing.R

# %%
# Location of pre-processed dataframe files
transformed_data_dir = "/home/main/data/StrokePsychosisELSATransformedData/"

# Directory to store the generated tables as html files. Must be writeable.
output_dir <- "/tmp/"

transformed_data_filename = paste(transformed_data_dir, "waves12345.rda", sep="")
load(file = transformed_data_filename)

strokeinpsychosis_surv_filename = paste(transformed_data_dir, "strokeinpsychosis_surv.rda", sep="")
load(file = strokeinpsychosis_surv_filename)

# %%
# Create variable defining stroke/psychosis categories for tables
descriptives <- strokeinpsychosis_surv %>%
  mutate(categories = case_when(strokeever_10 == 1 & psychosisever_10 == 0 ~ "Stroke only", # had stroke within 10 years, but no psychosis
                                strokeever_10 == 0 & psychosisever_10 == 1 ~ "Psychosis only", # had psychosis within 10 years, but no stroke
                                strokeever_10 == 1 & psychosisever_10 == 1 ~ "Stroke and Psychosis", # had stroke and psychosis within 10 years
                                strokeever_10 == 0 & psychosisever_10 == 0 ~ "No Stroke or Psychosis", # had no stroke or psychosis within 10 years (but may have had them after 10 years)
                                TRUE ~ "Error"))

# Pull required variables into one data frame
descriptives <- descriptives %>% 
  left_join(waves12345 %>% 
              select(idauniq, minstrokeage, ntotalstrokes, ntotalstrokesnozero, 
                     depressionever, anxietyever, totalwaves, allwavesparticipated, 
                     diedbeforeendfup), 
            by = "idauniq")

# Change 'unknown' ethnicities to NA
descriptives$ethnicgroup[descriptives$ethnicgroup == "Unknown"] <- NA

# %% [markdown]
# ### Table 1. Demographics and descriptive statistics for sample

# %%
table_1 <- descriptives %>%
  select(categories, w1age, age_cat, sex, ethnicgroup,
         netwealth_q5, smokingbaseline, vigorousactbaseline, alcoholbaseline) %>%
  tbl_summary(
    by = categories,
    digits = all_categorical() ~ c(0, 1),
    sort = everything() ~ "alphanumeric",
    label = list(w1age = "Age at Wave 1, median (IQR)",
                 age_cat = "Age categories, n (%)",
                 netwealth_q5 = "Net financial wealth (quintile), n (%)",
                 smokingbaseline = "Smoked cigarettes at baseline, n (%)",
                 vigorousactbaseline = "Level of vigorous activity at baseline, n (%)",
                 alcoholbaseline = "Level of alcohol consumption at baseline, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Table 1. Demographics and descriptive statistics for sample**") # %>%

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
table_1_filename = paste(output_dir, "RB_et_al_table_1.html", sep="")
gt::gtsave(as_gt(table_1), file = table_1_filename)
display_html(file = table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="hpeykhzmlq" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #hpeykhzmlq .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #hpeykhzmlq .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #hpeykhzmlq .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #hpeykhzmlq .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #hpeykhzmlq .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #hpeykhzmlq .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #hpeykhzmlq .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #hpeykhzmlq .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #hpeykhzmlq .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #hpeykhzmlq .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #hpeykhzmlq .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #hpeykhzmlq .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #hpeykhzmlq .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #hpeykhzmlq .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hpeykhzmlq .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #hpeykhzmlq .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #hpeykhzmlq .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hpeykhzmlq .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #hpeykhzmlq .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hpeykhzmlq .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #hpeykhzmlq .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hpeykhzmlq .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #hpeykhzmlq .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #hpeykhzmlq .gt_left {
#   text-align: left;
# }
#
# #hpeykhzmlq .gt_center {
#   text-align: center;
# }
#
# #hpeykhzmlq .gt_right {
#   text-align: right;
#   font-variant-numeric

# %% [markdown]
# ### Supplementary Table 1. Comparison of participants with and without missing baseline alcohol use data

# %%
# Missing alcohol data comparisons
suppl_table_1 <- strokeinpsychosis_surv %>%
  select(alcoholbaseline, w1age, sex, ethnicgroup, netwealth_q5, smokingbaseline, vigorousactbaseline, region,
         strokeever_10, psychosisever_10) %>%
  mutate(alcoholmissing = case_when(!is.na(alcoholbaseline) ~ 0,
                                    TRUE ~ 1)) %>%
  select(-alcoholbaseline) %>%
  tbl_summary(by = alcoholmissing,
              digits = all_categorical() ~ c(0, 1),
              label = list(w1age = "Wave 1 Age",
                           sex = "Sex",
                           ethnicgroup = "Ethnicity",
                           netwealth_q5 = "Net financial wealth (quintile)",
                           vigorousactbaseline = "Level of vigorous activity at baseline",
                           smokingbaseline = "Smoked cigarettes at baseline",
                           region = "Region",
                           strokeever_10 = "Reported stroke by 10y",
                           psychosisever_10 = "Reported psychosis by 10y"),
              missing = "no",
              percent = "col") %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Suppl Table 1. Comparison of participants with and without missing baseline alcohol use data**")

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
suppl_table_1_filename = paste(output_dir, "RB_et_al_suppl_table_1.html", sep="")
gt::gtsave(as_gt(suppl_table_1), file = suppl_table_1_filename)
display_html(file = suppl_table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="ipwoiikddb" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #ipwoiikddb .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #ipwoiikddb .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #ipwoiikddb .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #ipwoiikddb .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #ipwoiikddb .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #ipwoiikddb .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #ipwoiikddb .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #ipwoiikddb .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #ipwoiikddb .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #ipwoiikddb .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #ipwoiikddb .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #ipwoiikddb .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #ipwoiikddb .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #ipwoiikddb .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ipwoiikddb .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #ipwoiikddb .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #ipwoiikddb .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ipwoiikddb .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #ipwoiikddb .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ipwoiikddb .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #ipwoiikddb .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ipwoiikddb .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #ipwoiikddb .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ipwoiikddb .gt_left {
#   text-align: left;
# }
#
# #ipwoiikddb .gt_center {
#   text-align: center;
# }
#
# #ipwoiikddb .gt_right {
#   text-align: right;
#   font-variant-numeric

# %% [markdown]
# ### Supplementary Table 2. Stroke status and every-reported psychiatric diagnoses for sample

# %%
# Note some people in the 'no stroke/psychosis group' have stroke data as they had strokes after 10 years. These are recoded below, as this analysis is censored at 10 years.
descriptives$minstrokeage[descriptives$categories == "No Stroke or Psychosis" | descriptives$categories == "Psychosis only"] <- NA
descriptives$ntotalstrokes[descriptives$categories == "No Stroke or Psychosis" | descriptives$categories == "Psychosis only"] <- NA
descriptives$ntotalstrokesnozero[descriptives$categories == "No Stroke or Psychosis" | descriptives$categories == "Psychosis only"] <- NA

suppl_table_2 <- descriptives %>%
  select(categories, minstrokeage, ntotalstrokes, ntotalstrokesnozero, depressionever, anxietyever) %>%
  tbl_summary(
    by = categories,
    type = list(depressionever ~ "dichotomous",
                anxietyever ~ "dichotomous",
                ntotalstrokesnozero ~ "continuous"),
    statistic = list(ntotalstrokes ~ "{mean} ({sd})",
                     ntotalstrokesnozero ~ "{mean} ({sd})"),
    digits = list(ntotalstrokes ~ 1,
                  ntotalstrokesnozero ~ 1,
                  all_categorical() ~ c(0, 1)),
    sort = everything() ~ "alphanumeric",
    label = list(
                 minstrokeage = "Age at first stroke, median (IQR)",
                 ntotalstrokes = "Number of stroke recurrences, mean (SD)",
                 ntotalstrokesnozero = "Number of stroke recurrences (if >0), mean (SD)",
                 depressionever = "Ever-reported Depression, n (%)",
                 anxietyever = "Ever-reported Anxiety, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Suppl Table 2. Stroke characteristics and psychiatric comorbidities across Stroke and Psychosis groups**")

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
suppl_table_2_filename = paste(output_dir, "RB_et_al_suppl_table_2.html", sep="")
gt::gtsave(as_gt(suppl_table_2), file = suppl_table_2_filename)
display_html(file = suppl_table_2_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="zpnvewxudk" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #zpnvewxudk .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #zpnvewxudk .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #zpnvewxudk .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #zpnvewxudk .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #zpnvewxudk .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #zpnvewxudk .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #zpnvewxudk .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #zpnvewxudk .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #zpnvewxudk .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #zpnvewxudk .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #zpnvewxudk .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #zpnvewxudk .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #zpnvewxudk .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #zpnvewxudk .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #zpnvewxudk .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #zpnvewxudk .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #zpnvewxudk .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #zpnvewxudk .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #zpnvewxudk .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #zpnvewxudk .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #zpnvewxudk .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #zpnvewxudk .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #zpnvewxudk .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #zpnvewxudk .gt_left {
#   text-align: left;
# }
#
# #zpnvewxudk .gt_center {
#   text-align: center;
# }
#
# #zpnvewxudk .gt_right {
#   text-align: right;
#   font-variant-numeric

# %% [markdown]
# ### Supplementary Table 3. Study participation across stroke and psychosis groups.

# %%
suppl_table_3 <- descriptives %>%
  select(categories, totalwaves, allwavesparticipated, diedbeforeendfup) %>%
  tbl_summary(
    by = categories,
    type = totalwaves ~ "continuous",
    digits = list(totalwaves ~ 1,
                  all_categorical() ~ c(0, 1)),
        sort = everything() ~ "alphanumeric",
    label = list(
                 totalwaves = "Number of waves participated, median (IQR)",
                 allwavesparticipated = "Participated in all waves, n (%)",
                 diedbeforeendfup = "Died before Wave 6, n (%)")
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Suppl Table 3. Study participation across Stroke and Psychosis groups**")

suppl_table_3_filename = paste(output_dir, "RB_et_al_suppl_table_3.html", sep="")
gt::gtsave(as_gt(suppl_table_3), file = suppl_table_3_filename)
display_html(file = suppl_table_3_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="ojcvzvhwxi" style="padding-left:0px;padding-right:0px;padding-top:10px;padding-bottom:10px;overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #ojcvzvhwxi .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_caption {
#   padding-top: 4px;
#   padding-bottom: 4px;
# }
#
# #ojcvzvhwxi .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #ojcvzvhwxi .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #ojcvzvhwxi .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #ojcvzvhwxi .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #ojcvzvhwxi .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #ojcvzvhwxi .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #ojcvzvhwxi .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #ojcvzvhwxi .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   text-align: left;
# }
#
# #ojcvzvhwxi .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #ojcvzvhwxi .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #ojcvzvhwxi .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #ojcvzvhwxi .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #ojcvzvhwxi .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ojcvzvhwxi .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #ojcvzvhwxi .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #ojcvzvhwxi .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ojcvzvhwxi .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #ojcvzvhwxi .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ojcvzvhwxi .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #ojcvzvhwxi .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ojcvzvhwxi .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #ojcvzvhwxi .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #ojcvzvhwxi .gt_left {
#   text-align: left;
# }
#
# #ojcvzvhwxi .gt_center {
#   text-align: center;
# }
#
# #ojcvzvhwxi .gt_right {
#   text-align: right;
#   font-variant-numeric

# %% [markdown]
# ## Analysis platform details and software versions

# %%
version
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          2.1
# year           2022
# month          06
# day            23
# svn rev        82513
# language       R
# version.string R version 4.2.1 (2022-06-23)
# nickname       Funny-Looking Kid

# %%
packageVersion("dplyr")
# Out:
# [1] ‘1.1.1’

# %%
packageVersion("gtsummary")
# Out:
# [1] ‘1.7.0’

# %%
packageVersion("gt")
# Out:
# [1] ‘0.8.0’

# %%
packageVersion("IRdisplay")
# Out:
# [1] ‘1.1’

# %%
packageVersion("webshot2")
# Out:
# [1] ‘0.1.0’
