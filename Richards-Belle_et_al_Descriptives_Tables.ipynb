# %% [markdown]
# # Longitudinal associations of stroke and psychosis: a population-based study of older adults

# %% [markdown]
# ## Calculate descriptive statistics

# %% [markdown]
# Load necessary packages

# %%
library(dplyr)
library(gtsummary)
library(gt)
library(IRdisplay)
library(webshot2)

# %%
# Exporting tables to images from gtsummary requires PhantomJS to be installed
# It can be installed via the webshot2 package from the R prompt using the following commands
# library(webshot2)
# install_phantomjs()

# %% [markdown]
# Load pre-processed dataframes created by Stroke_Psychosis_ELSA_Pre-processing.R

# %%
# Location of pre-processed dataframe files
transformed_data_dir = "/home/main/data/StrokePsychosisELSATransformedData/"

# Directory to store the generated tables as html files. Must be writeable.
output_dir <- "/tmp/"

transformed_data_filename = paste(transformed_data_dir, "waves12345.rda", sep="")
load(file = transformed_data_filename)

strokeinpsychosis_surv_filename = paste(transformed_data_dir, "strokeinpsychosis_surv.rda", sep="")
load(file = strokeinpsychosis_surv_filename)

# %%
# Create variable defining stroke/psychosis categories for tables
strokeinpsychosis_surv <- strokeinpsychosis_surv %>%
  mutate(categories = case_when(strokeever_10 == 1 & psychosisever_10 == 0 ~ "Stroke only", # had stroke within 10 years, but no psychosis
                                strokeever_10 == 0 & psychosisever_10 == 1 ~ "Psychosis only", # had psychosis within 10 years, but no stroke
                                strokeever_10 == 1 & psychosisever_10 == 1 ~ "Stroke and Psychosis", # had stroke and psychosis within 10 years
                                strokeever_10 == 0 & psychosisever_10 == 0 ~ "No Stroke or Psychosis", # had no stroke or psychosis within 10 years (but may have had them after 10 years)
                                TRUE ~ "Error"))

# Merge with waves12345 which has the other required variables
strokeinpsychosis_surv <- merge(strokeinpsychosis_surv, waves12345, by="idauniq", all = TRUE)

# %% [markdown]
# ### Table 1. Demographics and descriptive statistics for sample

# %%
table_1 <- strokeinpsychosis_surv %>%
  select(categories, w1age.y, age_cat.y, Sex = sex.y, Ethnicity = ethnicgroup.y,
         netwealth_q5.y, smokingbaseline.y, vigorousactbaseline.y, alcoholbaseline.y) %>%
  tbl_summary(
    by = categories,
    sort = everything() ~ "alphanumeric",
    label = list(w1age.y = "Age at Wave 1, median (IQR)",
                 age_cat.y = "Age categories, n (%)",
                 netwealth_q5.y = "Net financial wealth (quintile), n (%)",
                 smokingbaseline.y = "Smoked cigarettes at baseline, n (%)",
                 vigorousactbaseline.y = "Level of vigorous activity at baseline, n (%)",
                 alcoholbaseline.y = "Level of alcohol consumption at baseline, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Table 1. Demographics and descriptive statistics for sample**")

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
table_1_filename = paste(output_dir, "RB_et_al_table_1.html", sep="")
gt::gtsave(as_gt(table_1), file = table_1_filename)
display_html(file = table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="vhpzeflqev" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #vhpzeflqev .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #vhpzeflqev .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #vhpzeflqev .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #vhpzeflqev .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #vhpzeflqev .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #vhpzeflqev .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #vhpzeflqev .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #vhpzeflqev .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #vhpzeflqev .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #vhpzeflqev .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #vhpzeflqev .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #vhpzeflqev .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #vhpzeflqev .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #vhpzeflqev .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #vhpzeflqev .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #vhpzeflqev .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #vhpzeflqev .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #vhpzeflqev .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #vhpzeflqev .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #vhpzeflqev .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #vhpzeflqev .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #vhpzeflqev .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #vhpzeflqev .gt_left {
#   text-align: left;
# }
#
# #vhpzeflqev .gt_center {
#   text-align: center;
# }
#
# #vhpzeflqev .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #vhpzeflqev .gt_font_normal {
#   font-weight: normal;
# }
#
# #vhpzeflqev .gt_font_bold {
#   font-weight: bold;
# }
#
# #vhpzeflqev .gt_font_italic {
#   font-

# %% [markdown]
# ### Table 2. Stroke status and every-reported psychiatric diagnoses for sample

# %%
table_2 <- strokeinpsychosis_surv %>%
  select(categories, minstrokeage, ntotalstrokes, ntotalstrokesnozero, depressionever, anxietyever) %>%
  tbl_summary(
    by = categories,
    type = list(depressionever ~ "dichotomous",
                anxietyever ~ "dichotomous",
                ntotalstrokesnozero ~ "continuous"),
    statistic = list(ntotalstrokes ~ "{mean} ({sd})",
                     ntotalstrokesnozero ~ "{mean} ({sd})"),
    digits = list(ntotalstrokes ~ 1,
                  ntotalstrokesnozero ~ 1),
    sort = everything() ~ "alphanumeric",
    label = list(
                 minstrokeage = "Age at first stroke, median (IQR)",
                 ntotalstrokes = "Number of stroke recurrences, mean (SD)",
                 ntotalstrokesnozero = "Number of stroke recurrences (if >0), mean (SD)",
                 depressionever = "Ever-reported Depression, n (%)",
                 anxietyever = "Ever-reported Anxiety, n (%)"),
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Table 2. Stroke characteristics and psychiatric comorbidities across Stroke and Psychosis groups**") #%>%

# This save the output of the gtsummary generated table as a html file and reloads it to display on the notebook
table_2_filename = paste(output_dir, "RB_et_al_table_2.html", sep="")
gt::gtsave(as_gt(table_2), file = table_2_filename)
display_html(file = table_2_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="butizirbyf" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #butizirbyf .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #butizirbyf .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #butizirbyf .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #butizirbyf .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #butizirbyf .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #butizirbyf .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #butizirbyf .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #butizirbyf .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #butizirbyf .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #butizirbyf .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #butizirbyf .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #butizirbyf .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #butizirbyf .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #butizirbyf .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #butizirbyf .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #butizirbyf .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #butizirbyf .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #butizirbyf .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #butizirbyf .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #butizirbyf .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #butizirbyf .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #butizirbyf .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #butizirbyf .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #butizirbyf .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #butizirbyf .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #butizirbyf .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #butizirbyf .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #butizirbyf .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #butizirbyf .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #butizirbyf .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #butizirbyf .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #butizirbyf .gt_left {
#   text-align: left;
# }
#
# #butizirbyf .gt_center {
#   text-align: center;
# }
#
# #butizirbyf .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #butizirbyf .gt_font_normal {
#   font-weight: normal;
# }
#
# #butizirbyf .gt_font_bold {
#   font-weight: bold;
# }
#
# #butizirbyf .gt_font_italic {
#   font-

# %% [markdown]
# ### Supplementary Table 1. Study participation across stroke and psychosis groups.

# %%
suppl_table_1 <- strokeinpsychosis_surv %>%
  select(categories, totalwaves, allwavesparticipated, diedbeforeendfup) %>%
  tbl_summary(
    by = categories,
    type = totalwaves ~ "continuous",
    digits = totalwaves ~ 1,
    sort = everything() ~ "alphanumeric",
    label = list(
                 totalwaves = "Number of waves participated, median (IQR)",
                 allwavesparticipated = "Participated in all waves, n (%)",
                 diedbeforeendfup = "Died before Wave 6, n (%)")
  ) %>%
  bold_labels() %>%
  italicize_levels() %>%
  modify_caption("**Supplementary Table 1. Study participation across Stroke and Psychosis groups**") # %>%

suppl_table_1_filename = paste(output_dir, "RB_et_al_suppl_table_1.html", sep="")
gt::gtsave(as_gt(suppl_table_1), file = suppl_table_1_filename)
display_html(file = suppl_table_1_filename)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>body{background-color:white;}</style>
#
#
# </head>
# <body>
# <div id="pgdqekasej" style="overflow-x:auto;overflow-y:auto;width:auto;height:auto;">
#   <style>html {
#   font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Oxygen, Ubuntu, Cantarell, 'Helvetica Neue', 'Fira Sans', 'Droid Sans', Arial, sans-serif;
# }
#
# #pgdqekasej .gt_table {
#   display: table;
#   border-collapse: collapse;
#   margin-left: auto;
#   margin-right: auto;
#   color: #333333;
#   font-size: 16px;
#   font-weight: normal;
#   font-style: normal;
#   background-color: #FFFFFF;
#   width: auto;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #A8A8A8;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #A8A8A8;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_heading {
#   background-color: #FFFFFF;
#   text-align: center;
#   border-bottom-color: #FFFFFF;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_title {
#   color: #333333;
#   font-size: 125%;
#   font-weight: initial;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-color: #FFFFFF;
#   border-bottom-width: 0;
# }
#
# #pgdqekasej .gt_subtitle {
#   color: #333333;
#   font-size: 85%;
#   font-weight: initial;
#   padding-top: 0;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-color: #FFFFFF;
#   border-top-width: 0;
# }
#
# #pgdqekasej .gt_bottom_border {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_col_headings {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_col_heading {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 6px;
#   padding-left: 5px;
#   padding-right: 5px;
#   overflow-x: hidden;
# }
#
# #pgdqekasej .gt_column_spanner_outer {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: normal;
#   text-transform: inherit;
#   padding-top: 0;
#   padding-bottom: 0;
#   padding-left: 4px;
#   padding-right: 4px;
# }
#
# #pgdqekasej .gt_column_spanner_outer:first-child {
#   padding-left: 0;
# }
#
# #pgdqekasej .gt_column_spanner_outer:last-child {
#   padding-right: 0;
# }
#
# #pgdqekasej .gt_column_spanner {
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: bottom;
#   padding-top: 5px;
#   padding-bottom: 5px;
#   overflow-x: hidden;
#   display: inline-block;
#   width: 100%;
# }
#
# #pgdqekasej .gt_group_heading {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #pgdqekasej .gt_empty_group_heading {
#   padding: 0.5px;
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   vertical-align: middle;
# }
#
# #pgdqekasej .gt_from_md > :first-child {
#   margin-top: 0;
# }
#
# #pgdqekasej .gt_from_md > :last-child {
#   margin-bottom: 0;
# }
#
# #pgdqekasej .gt_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   margin: 10px;
#   border-top-style: solid;
#   border-top-width: 1px;
#   border-top-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 1px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 1px;
#   border-right-color: #D3D3D3;
#   vertical-align: middle;
#   overflow-x: hidden;
# }
#
# #pgdqekasej .gt_stub {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pgdqekasej .gt_stub_row_group {
#   color: #333333;
#   background-color: #FFFFFF;
#   font-size: 100%;
#   font-weight: initial;
#   text-transform: inherit;
#   border-right-style: solid;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
#   padding-left: 5px;
#   padding-right: 5px;
#   vertical-align: top;
# }
#
# #pgdqekasej .gt_row_group_first td {
#   border-top-width: 2px;
# }
#
# #pgdqekasej .gt_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pgdqekasej .gt_first_summary_row {
#   border-top-style: solid;
#   border-top-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_first_summary_row.thick {
#   border-top-width: 2px;
# }
#
# #pgdqekasej .gt_last_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_grand_summary_row {
#   color: #333333;
#   background-color: #FFFFFF;
#   text-transform: inherit;
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pgdqekasej .gt_first_grand_summary_row {
#   padding-top: 8px;
#   padding-bottom: 8px;
#   padding-left: 5px;
#   padding-right: 5px;
#   border-top-style: double;
#   border-top-width: 6px;
#   border-top-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_striped {
#   background-color: rgba(128, 128, 128, 0.05);
# }
#
# #pgdqekasej .gt_table_body {
#   border-top-style: solid;
#   border-top-width: 2px;
#   border-top-color: #D3D3D3;
#   border-bottom-style: solid;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_footnotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_footnote {
#   margin: 0px;
#   font-size: 90%;
#   padding-left: 4px;
#   padding-right: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pgdqekasej .gt_sourcenotes {
#   color: #333333;
#   background-color: #FFFFFF;
#   border-bottom-style: none;
#   border-bottom-width: 2px;
#   border-bottom-color: #D3D3D3;
#   border-left-style: none;
#   border-left-width: 2px;
#   border-left-color: #D3D3D3;
#   border-right-style: none;
#   border-right-width: 2px;
#   border-right-color: #D3D3D3;
# }
#
# #pgdqekasej .gt_sourcenote {
#   font-size: 90%;
#   padding-top: 4px;
#   padding-bottom: 4px;
#   padding-left: 5px;
#   padding-right: 5px;
# }
#
# #pgdqekasej .gt_left {
#   text-align: left;
# }
#
# #pgdqekasej .gt_center {
#   text-align: center;
# }
#
# #pgdqekasej .gt_right {
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
#
# #pgdqekasej .gt_font_normal {
#   font-weight: normal;
# }
#
# #pgdqekasej .gt_font_bold {
#   font-weight: bold;
# }
#
# #pgdqekasej .gt_font_italic {
#   font-

# %% [markdown]
# ## Analysis platform details and software versions

# %%
version
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          4
# minor          0.3
# year           2020
# month          10
# day            10
# svn rev        79318
# language       R
# version.string R version 4.0.3 (2020-10-10)
# nickname       Bunny-Wunnies Freak Out

# %%
packageVersion("dplyr")
# Out:
# [1] ‘1.0.9’

# %%
packageVersion("gtsummary")
# Out:
# [1] ‘1.6.1’

# %%
packageVersion("gt")
# Out:
# [1] ‘0.6.0’

# %%
packageVersion("IRdisplay")
# Out:
# [1] ‘0.7.0’

# %%
packageVersion("webshot2")
# Out:
# [1] ‘0.1.0’
